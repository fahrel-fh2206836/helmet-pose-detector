# %%
import pandas as pd

lat = pd.read_csv("model_latency_results.csv")
acc = pd.read_csv("model_accuracy_results.csv")

# merge on the "model" column
df = lat.merge(acc, on="model")

df

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 7))

# scatter plot
plt.scatter(
    df["mean_latency_ms"], 
    df["val_accuracy"], 
    s=200, 
    alpha=0.8
)

# label each point
for i in range(len(df)):
    plt.text(
        df["mean_latency_ms"][i] + 0.05, 
        df["val_accuracy"][i], 
        df["model"][i].replace(".pth",""),
        fontsize=9
    )

plt.xlabel("Inference Time (ms)", fontsize=14)
plt.ylabel("Validation Accuracy (%)", fontsize=14)
plt.title("Model Performance Tradeoff: Accuracy vs Inference Latency", fontsize=16)

plt.grid(True, linestyle="--", alpha=0.4)

# optional: highlight ideal quadrant
plt.axvline(x=df["mean_latency_ms"].median(), color='gray', linestyle='--', linewidth=1)
plt.axhline(y=df["val_accuracy"].median(), color='gray', linestyle='--', linewidth=1)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 7
#       3 plt.figure(figsize=(10, 7))
#       5 # scatter plot
#       6 plt.scatter(
# ----> 7     df["mean_latency_ms"],
#       8     df["val_accuracy"],
#       9     s=200,
#      10     alpha=0.8
#      11 )
#      13 # label each point
#      14 for i in range(len(df)):
#
# NameError: name 'df' is not defined

# %%
import seaborn as sns

families = df["model"].apply(lambda x: x.split("_")[0])

plt.figure(figsize=(10,7))
sns.scatterplot(
    data=df,
    x="mean_latency_ms",
    y="val_accuracy",
    hue=families,
    s=200
)
